# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetic_data.csv')

# %%
df1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                      1  ...          No      No                   No
# 1                      3  ...          No      Up                   No
# 2                      2  ...          No      No                   No
# 3                      2  ...          No      Up                   No
# 4                      1  ...          No  Steady                   No
# ...                  ...  ...         ...     ...                  ...
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 0                        No                        No
# 1                        No                        No
# 2                        No                        No
# 3                        No                        No
# 4                        No                        No
# ...                     ...                       ...
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 0                            No                      No      No          No
# 1                            No                      No      Ch         Yes
# 2                            No                      No      No         Yes
# 3                            No                      No      Ch         Yes
# 4                            No                      No      Ch         Yes
# ...                         ...                     ...     ...         ...
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 50 columns]

# %%
df1['readmitted'] = df1['readmitted'].replace('>30', 0)
df1['readmitted'] = df1['readmitted'].replace('<30', 1)
df1['readmitted'] = df1['readmitted'].replace('NO', 0)

# %%
df1.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# acarbose                    0
# miglitol                    0
# troglitazone                0
# tolazamide                  0
# examide                     0
# citoglipton                 0
# insulin                     0
# glyburide-metformin         0
# glipizide-metformin         0
# glimepiride-pioglitazone    0
# metformin-rosiglitazone     0
# metformin-pioglitazone      0
# change                      0
# diabetesMed                 0
# readmitted                  0
# dtype: int64

# %%
df= df1[["race","gender","age" ,"time_in_hospital","num_lab_procedures","num_procedures","num_medications","number_emergency","diag_1","diag_2", 
         "metformin","repaglinide","nateglinide","chlorpropamide","glimepiride","acetohexamide","glipizide","glyburide","tolbutamide","pioglitazone","rosiglitazone","acarbose","miglitol","troglitazone","tolazamide","examide","citoglipton" ,"insulin" ,"glyburide-metformin","glipizide-metformin","glimepiride-pioglitazone","metformin-rosiglitazone"  ,"metformin-pioglitazone"                     
,"diag_3","change","diabetesMed","readmitted","max_glu_serum","A1Cresult","discharge_disposition_id","number_diagnoses","number_outpatient","number_inpatient","weight"]]

# %%
df
# Out:
#                    race  gender      age  time_in_hospital  \
# 0             Caucasian  Female   [0-10)                 1
# 1             Caucasian  Female  [10-20)                 3
# 2       AfricanAmerican  Female  [20-30)                 2
# 3             Caucasian    Male  [30-40)                 2
# 4             Caucasian    Male  [40-50)                 1
# ...                 ...     ...      ...               ...
# 101761  AfricanAmerican    Male  [70-80)                 3
# 101762  AfricanAmerican  Female  [80-90)                 5
# 101763        Caucasian    Male  [70-80)                 1
# 101764        Caucasian  Female  [80-90)                10
# 101765        Caucasian    Male  [70-80)                 6
#
#         num_lab_procedures  num_procedures  num_medications  number_emergency  \
# 0                       41               0                1                 0
# 1                       59               0               18                 0
# 2                       11               5               13                 0
# 3                       44               1               16                 0
# 4                       51               0                8                 0
# ...                    ...             ...              ...               ...
# 101761                  51               0               16                 0
# 101762                  33               3               18                 0
# 101763                  53               0                9                 0
# 101764                  45               2               21                 0
# 101765                  13               3                3                 0
#
#         diag_1  diag_2  ... change diabetesMed readmitted max_glu_serum  \
# 0       250.83       ?  ...     No          No          0          None
# 1          276  250.01  ...     Ch         Yes          0          None
# 2          648     250  ...     No         Yes          0          None
# 3            8  250.43  ...     Ch         Yes          0          None
# 4          197     157  ...     Ch         Yes          0          None
# ...        ...     ...  ...    ...         ...        ...           ...
# 101761  250.13     291  ...     Ch         Yes          0          None
# 101762     560     276  ...     No         Yes          0          None
# 101763      38     590  ...     Ch         Yes          0          None
# 101764     996     285  ...     Ch         Yes          0          None
# 101765     530     530  ...     No          No          0          None
#
#        A1Cresult discharge_disposition_id number_diagnoses number_outpatient  \
# 0           None                       25                1                 0
# 1           None                        1                9                 0
# 2           None                        1                6                 2
# 3           None                        1                7                 0
# 4           None                        1                5                 0
# ...          ...                      ...              ...               ...
# 101761        >8                        3                9                 0
# 101762      None                        4                9                 0
# 101763      None                        1               13                 1
# 101764      None                        3                9                 0
# 101765      None                        1                9                 0
#
#        number_inpatient weight
# 0                     0      ?
# 1                     0      ?
# 2                     1      ?
# 3                     0      ?
# 4                     0      ?
# ...                 ...    ...
# 101761                0      ?
# 101762                1      ?
# 101763                0      ?
# 101764                1      ?
# 101765                0      ?
#
# [101766 rows x 44 columns]

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# %%
df["metformin"]=label_encoder.fit_transform(df["metformin"])
df["repaglinide"]=label_encoder.fit_transform(df["repaglinide"])
df["nateglinide"]=label_encoder.fit_transform(df["nateglinide"])
df["chlorpropamide"]=label_encoder.fit_transform(df["chlorpropamide"])
df["glimepiride"]=label_encoder.fit_transform(df["glimepiride"])
df["acetohexamide"]=label_encoder.fit_transform(df["acetohexamide"])
df["glipizide"]=label_encoder.fit_transform(df["glipizide"])
df["glyburide"]=label_encoder.fit_transform(df["glyburide"])
df["tolbutamide"]=label_encoder.fit_transform(df["tolbutamide"])
df["pioglitazone"]=label_encoder.fit_transform(df["pioglitazone"])
df["rosiglitazone"]=label_encoder.fit_transform(df["rosiglitazone"])
df["acarbose"]=label_encoder.fit_transform(df["acarbose"])
df["miglitol"]=label_encoder.fit_transform(df["miglitol"])
df["troglitazone"]=label_encoder.fit_transform(df["troglitazone"])
df["tolazamide"]=label_encoder.fit_transform(df["tolazamide"])
df["examide"]=label_encoder.fit_transform(df["examide"])
df["citoglipton"]=label_encoder.fit_transform(df["citoglipton"])
df["insulin"]=label_encoder.fit_transform(df["insulin"])
df["glyburide-metformin"]=label_encoder.fit_transform(df["glyburide-metformin"])
df["glipizide-metformin"]=label_encoder.fit_transform(df["glipizide-metformin"])
df["glimepiride-pioglitazone"]=label_encoder.fit_transform(df["glipizide-metformin"])
df["metformin-rosiglitazone"]=label_encoder.fit_transform(df["metformin-rosiglitazone"])
df["metformin-pioglitazone"]=label_encoder.fit_transform(df["metformin-pioglitazone"])
df["max_glu_serum"]=label_encoder.fit_transform(df["max_glu_serum"])
df["A1Cresult"]=label_encoder.fit_transform(df["A1Cresult"])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['change'] = df['change'].replace('Ch', 1)
df['change'] = df['change'].replace('No', 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["gender"].value_counts()
# Out:
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
df["gender"] = df["gender"].drop(df[df["gender"] == "Unknown/Invalid"].index, axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['gender'] = df['gender'].replace('Male', 1)
df['gender'] = df['gender'].replace('Female', 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['readmitted'] = df['readmitted'].replace('>30', 0)
df['readmitted'] = df['readmitted'].replace('<30', 1)
df['readmitted'] = df['readmitted'].replace('NO', 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['diabetesMed'] = df['diabetesMed'].replace('Yes', 1)
df['diabetesMed'] = df['diabetesMed'].replace('No', 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.dropna(subset = ['gender'], inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df["age"].value_counts()
# Out:
# [70-80)     26066
# [60-70)     22482
# [50-60)     17256
# [80-90)     17197
# [40-50)      9685
# [30-40)      3775
# [90-100)     2793
# [20-30)      1657
# [10-20)       691
# [0-10)        161
# Name: age, dtype: int64

# %%
for i in range(0,10):
    df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["age"].value_counts()
# Out:
# 8     26066
# 7     22482
# 6     17256
# 9     17197
# 5      9685
# 4      3775
# 10     2793
# 3      1657
# 2       691
# 1       161
# Name: age, dtype: int64

# %%
df
# Out:
#                    race  gender  age  time_in_hospital  num_lab_procedures  \
# 0             Caucasian     0.0    1                 1                  41
# 1             Caucasian     0.0    2                 3                  59
# 2       AfricanAmerican     0.0    3                 2                  11
# 3             Caucasian     1.0    4                 2                  44
# 4             Caucasian     1.0    5                 1                  51
# ...                 ...     ...  ...               ...                 ...
# 101761  AfricanAmerican     1.0    8                 3                  51
# 101762  AfricanAmerican     0.0    9                 5                  33
# 101763        Caucasian     1.0    8                 1                  53
# 101764        Caucasian     0.0    9                10                  45
# 101765        Caucasian     1.0    8                 6                  13
#
#         num_procedures  num_medications  number_emergency  diag_1  diag_2  \
# 0                    0                1                 0  250.83       ?
# 1                    0               18                 0     276  250.01
# 2                    5               13                 0     648     250
# 3                    1               16                 0       8  250.43
# 4                    0                8                 0     197     157
# ...                ...              ...               ...     ...     ...
# 101761               0               16                 0  250.13     291
# 101762               3               18                 0     560     276
# 101763               0                9                 0      38     590
# 101764               2               21                 0     996     285
# 101765               3                3                 0     530     530
#
#         ...  change  diabetesMed  readmitted  max_glu_serum  A1Cresult  \
# 0       ...       0            0           0              2          2
# 1       ...       1            1           0              2          2
# 2       ...       0            1           0              2          2
# 3       ...       1            1           0              2          2
# 4       ...       1            1           0              2          2
# ...     ...     ...          ...         ...            ...        ...
# 101761  ...       1            1           0              2          1
# 101762  ...       0            1           0              2          2
# 101763  ...       1            1           0              2          2
# 101764  ...       1            1           0              2          2
# 101765  ...       0            0           0              2          2
#
#         discharge_disposition_id  number_diagnoses  number_outpatient  \
# 0                             25                 1                  0
# 1                              1                 9                  0
# 2                              1                 6                  2
# 3                              1                 7                  0
# 4                              1                 5                  0
# ...                          ...               ...                ...
# 101761                         3                 9                  0
# 101762                         4                 9                  0
# 101763                         1                13                  1
# 101764                         3                 9                  0
# 101765                         1                 9                  0
#
#         number_inpatient  weight
# 0                      0       ?
# 1                      0       ?
# 2                      1       ?
# 3                      0       ?
# 4                      0       ?
# ...                  ...     ...
# 101761                 0       ?
# 101762                 1       ?
# 101763                 0       ?
# 101764                 1       ?
# 101765                 0       ?
#
# [101763 rows x 44 columns]

# %%
df.shape
# Out:
# (101763, 44)

# %%
rdx = df[df['race'] == '?'].index

# %%
rdx = df[df['race'] == '?'].index
df = df.drop(rdx, axis = 0)

# %%
df['race'].value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# Hispanic            2037
# Other               1505
# Asian                641
# Name: race, dtype: int64

# %%
df['race'] = df['race'].replace('Caucasian', 1)
df['race'] = df['race'].replace('AfricanAmerican', 2)
df['race'] = df['race'].replace('Hispanic', 3)
df['race'] = df['race'].replace('Asian', 4)
df['race'] = df['race'].replace('Other', 5)

# %%
df["diag_1"]=df["diag_1"].drop(df[df["diag_1"]=="?"].index,axis=0)
df["diag_2"]=df["diag_2"].drop(df[df["diag_2"]=="?"].index,axis=0)
df["diag_3"]=df["diag_3"].drop(df[df["diag_3"]=="?"].index,axis=0)

# %%
def map_diagnosis(data, cols):
  for col in cols:
        data.loc[(data[col].str.contains("V")) | (data[col].str.contains("E")), col] = -1
        data[col] = data[col].astype(np.float16)

# %%
map_diagnosis(df,["diag_1","diag_2","diag_3"])

# %%
df["diag_1"]=df["diag_1"].astype(float)
df["diag_2"]=df["diag_2"].astype(float)
df["diag_3"]=df["diag_3"].astype(float)
df=df.dropna()

# %%
df["diag_1"]=df["diag_1"].apply(lambda x:0 if x<=139 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:1 if  x>140 and x<=239 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:2 if  x>239 and x<=279 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:3 if  x>279 and x<=289 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:4 if  x>289 and x<=319 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:5 if  x>319 and x<=389 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:6 if  x>389 and x<=459 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:7 if  x>459 and x<=519 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:8 if  x>519 and x<=579 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:9 if  x>=580 and x<=629 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:10 if  x>=630 and x<=679 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:11 if  x>=680 and x<=709 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:12 if  x>=710 and x<=739 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:13 if  x>=740 and x<=759 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:14 if  x>=760 and x<=779 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:15 if  x>=780 and x<=799 else x)
df["diag_1"]=df["diag_1"].apply(lambda x:16 if  x>=800 and x<=999 else x)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#replace diag 2
df["diag_2"]=df["diag_2"].apply(lambda x:9 if  x>=580 and x<=629 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:10 if  x>=630 and x<=679 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:11 if  x>=680 and x<=709 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:12 if  x>=710 and x<=739 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:13 if  x>=740 and x<=759 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:14 if  x>=760 and x<=779 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:15 if  x>=780 and x<=799 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:16 if  x>=800 and x<=999 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:0 if x<=139 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:1 if  x>140 and x<=239 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:2 if  x>239 and x<=279 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:3 if  x>279 and x<=289 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:4 if  x>289 and x<=319 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:5 if  x>319 and x<=389 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:6 if  x>389 and x<=459 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:7 if  x>459 and x<=519 else x)
df["diag_2"]=df["diag_2"].apply(lambda x:8 if  x>519 and x<=579 else x)

# %%
#replace diag_3
df["diag_3"]=df["diag_3"].apply(lambda x:0 if x<=139 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:1 if  x>140 and x<=239 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:2 if  x>239 and x<=279 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:3 if  x>279 and x<=289 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:4 if  x>289 and x<=319 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:5 if  x>319 and x<=389 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:6 if  x>389 and x<=459 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:7 if  x>459 and x<=519 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:8 if  x>519 and x<=579 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:9 if  x>=580 and x<=629 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:10 if  x>=630 and x<=679 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:11 if  x>=680 and x<=709 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:12 if  x>=710 and x<=739 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:13 if  x>=740 and x<=759 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:14 if  x>=760 and x<=779 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:15 if  x>=780 and x<=799 else x)
df["diag_3"]=df["diag_3"].apply(lambda x:16 if  x>=800 and x<=999 else x)

# %%
#df.drop(['diag_1',"diag_2","diag_3"],axis=1,inplace=True)

# %%
df["race"].value_counts()
# Out:
# 1    75079
# 2    18881
# 3     1984
# 5     1483
# 4      625
# Name: race, dtype: int64

# %%
df3=df[["readmitted","race","age","time_in_hospital","num_lab_procedures","num_medications","metformin","repaglinide",'nateglinide','chlorpropamide','glimepiride','glipizide'
,'glyburide','pioglitazone','rosiglitazone','acarbose','miglitol','insulin','glyburide-metformin','glipizide-metformin','glimepiride-pioglitazone','diabetesMed',"diag_1","diag_2","diag_3","number_emergency", "num_procedures","discharge_disposition_id","gender","number_diagnoses","number_outpatient","number_inpatient"]]

# %%
df3
# Out:
#         readmitted  race  age  time_in_hospital  num_lab_procedures  \
# 1                0     1    2                 3                  59
# 2                0     2    3                 2                  11
# 3                0     1    4                 2                  44
# 4                0     1    5                 1                  51
# 5                0     1    6                 3                  31
# ...            ...   ...  ...               ...                 ...
# 101761           0     2    8                 3                  51
# 101762           0     2    9                 5                  33
# 101763           0     1    8                 1                  53
# 101764           0     1    9                10                  45
# 101765           0     1    8                 6                  13
#
#         num_medications  metformin  repaglinide  nateglinide  chlorpropamide  \
# 1                    18          1            1            1               1
# 2                    13          1            1            1               1
# 3                    16          1            1            1               1
# 4                     8          1            1            1               1
# 5                    16          1            1            1               1
# ...                 ...        ...          ...          ...             ...
# 101761               16          2            1            1               1
# 101762               18          1            1            1               1
# 101763                9          2            1            1               1
# 101764               21          1            1            1               1
# 101765                3          1            1            1               1
#
#         ...  diag_1  diag_2  diag_3  number_emergency  num_procedures  \
# 1       ...     2.0     2.0     2.0                 0               0
# 2       ...    10.0     2.0     0.0                 0               5
# 3       ...     0.0     2.0     6.0                 0               1
# 4       ...     1.0     1.0     2.0                 0               0
# 5       ...     6.0     6.0     2.0                 0               6
# ...     ...     ...     ...     ...               ...             ...
# 101761  ...     2.0     4.0     6.0                 0               0
# 101762  ...     8.0     2.0    15.0                 0               3
# 101763  ...     0.0     0.0     4.0                 0               0
# 101764  ...    16.0     3.0    16.0                 0               2
# 101765  ...     8.0     8.0    15.0                 0               3
#
#         discharge_disposition_id  gender  number_diagnoses  number_outpatient  \
# 1                              1     0.0                 9                  0
# 2                              1     0.0                 6                  2
# 3                              1     1.0                 7                  0
# 4                              1     1.0                 5                  0
# 5                              1     1.0                 9                  0
# ...                          ...     ...               ...                ...
# 101761                         3     1.0                 9                  0
# 101762                         4     0.0                 9                  0
# 101763                         1     1.0                13                  1
# 101764                         3     0.0                 9                  0
# 101765                         1     1.0                 9                  0
#
#         number_inpatient
# 1                      0
# 2                      1
# 3                      0
# 4                      0
# 5                      0
# ...                  ...
# 101761                 0
# 101762                 1
# 101763                 0
# 101764                 1
# 101765                 0
#
# [98052 rows x 32 columns]

# %%
cor = df3.corr()
cor
# Out:
#                           readmitted      race       age  time_in_hospital  \
# readmitted                  1.000000 -0.006677  0.013550          0.043398
# race                       -0.006677  1.000000 -0.138316         -0.002497
# age                         0.013550 -0.138316  1.000000          0.096687
# time_in_hospital            0.043398 -0.002497  0.096687          1.000000
# num_lab_procedures          0.019902  0.012856  0.016611          0.318632
# num_medications             0.037773 -0.054415  0.019955          0.464212
# metformin                  -0.024184 -0.004333 -0.061277         -0.005873
# repaglinide                 0.010457 -0.006352  0.045084          0.030792
# nateglinide                 0.000331  0.009382  0.016085          0.004231
# chlorpropamide             -0.004841 -0.004704  0.012853          0.004172
# glimepiride                -0.008011 -0.012083  0.031088          0.010074
# glipizide                   0.000441 -0.001868  0.040736          0.010539
# glyburide                  -0.003827 -0.015087  0.059209          0.016273
# pioglitazone               -0.006467 -0.015761  0.008723          0.005161
# rosiglitazone              -0.005412 -0.008037  0.000469          0.006148
# acarbose                   -0.004010 -0.008373  0.006878          0.005781
# miglitol                   -0.005385 -0.001902  0.007214          0.003241
# insulin                     0.003152  0.016569 -0.019074          0.047196
# glyburide-metformin        -0.001739  0.008129 -0.002220         -0.001647
# glipizide-metformin        -0.001308 -0.005223  0.001910         -0.000736
# glimepiride-pioglitazone   -0.001308 -0.005223  0.001910         -0.000736
# diabetesMed                 0.027059  0.006061 -0.020812          0.062335
# diag_1                     -0.022282 -0.000461  0.019843         -0.126978
# diag_2                     -0.007418 -0.025260  0.110208         -0.000740
# diag_3                      0.016961 -0.000781  0.046703          0.086322
# number_emergency            0.060557  0.020388 -0.091750         -0.010508
# num_procedures             -0.012470 -0.013973 -0.042699          0.191164
# discharge_disposition_id    0.050422 -0.012343  0.114274          0.162903
# gender                     -0.002544 -0.031277 -0.052631         -0.028961
# number_diagnoses            0.046491 -0.080525  0.202696          0.211225
# number_outpatient           0.018408 -0.043665  0.020007         -0.010913
# number_inpatient            0.163811 -0.004324 -0.049168          0.072282
#
#                           num_lab_procedures  num_medications  metformin  \
# readmitted                          0.019902         0.037773  -0.024184
# race                                0.012856        -0.054415  -0.004333
# age                                 0.016611         0.019955  -0.061277
# time_in_hospital                    0.318632         0.464212  -0.005873
# num_lab_procedures                  1.000000         0.267863  -0.042500
# num_medications                     0.267863         1.000000   0.059138
# metformin                          -0.042500         0.059138   1.000000
# repaglinide                         0.013613         0.021436   0.001906
# nateglinide                        -0.005806         0.021889   0.019178
# chlorpropamide                      0.000421         0.002650  -0.009501
# glimepiride                        -0.000878         0.037640   0.038843
# glipizide                           0.008934         0.048335   0.065751
# glyburide                          -0.005189         0.027575   0.116513
# pioglitazone                       -0.014561         0.061996   0.052870
# rosiglitazone                      -0.007910         0.050198   0.084172
# acarbose                           -0.000080         0.017608   0.009644
# miglitol                           -0.002782         0.002540   0.004414
# insulin                             0.034391         0.080230   0.003661
# glyburide-metformin                -0.009571         0.008669  -0.021002
# glipizide-metformin                -0.007681         0.003435  -0.003137
# glimepiride-pioglitazone           -0.007681         0.003435  -0.003137
# diabetesMed                         0.031936         0.189318   0.246582
# diag_1                             -0.066956        -0.005420   0.031626
# diag_2                              0.018852         0.067330  -0.024821
# diag_3                              0.041618         0.068086  -0.020398
# number_emergency                   -0.002142         0.012127  -0.008534
# num_procedures                      0.058710         0.382952  -0.037598
# discharge_disposition_id            0.022601         0.106696  -0.009119
# gender                             -0.002358        -0.022085   0.000654
# number_diagnoses                    0.150257         0.241501  -0.070561
# number_outpatient                  -0.008625         0.042652  -0.011537
# number_inpatient                    0.039198         0.062905  -0.065709
#
#                           repaglinide  nateglinide  chlorpropamide  ...  \
# readmitted                   0.010457     0.000331       -0.004841  ...
# race                        -0.006352     0.009382       -0.004704  ...
# age                          0.045084     0.016085        0.012853  ...
# time_in_hospital             0.030792     0.004231        0.004172  ...
# num_lab_procedures           0.013613    -0.005806        0.000421  ...
# num_medications              0.021436     0.021889        0.002650  ...
# metformin                    0.001906     0.019178       -0.009501  ...
# repaglinide                  1.000000    -0.000741       -0.003188  ...
# nateglinide                 -0.000741     1.000000       -0.002224  ...
# chlorpropamide              -0.003188    -0.002224        1.000000  ...
# glimepiride                 -0.006994     0.006361       -0.005780  ...
# glipizide                   -0.013062    -0.013159       -0.008360  ...
# glyburide                   -0.018199    -0.018030       -0.005404  ...
# pioglitazone                 0.016662     0.024308       -0.006183  ...
# rosiglitazone                0.013014     0.013499        0.000657  ...
# acarbose                     0.010666    -0.000278       -0.001478  ...
# miglitol                     0.012560     0.009886       -0.000418  ...
# insulin                     -0.003087     0.000066       -0.007536  ...
# glyburide-metformin         -0.004045    -0.006577       -0.002262  ...
# glipizide-metformin         -0.001328    -0.000926       -0.000318  ...
# glimepiride-pioglitazone    -0.001328    -0.000926       -0.000318  ...
# diabetesMed                  0.063280     0.044143        0.015181  ...
# diag_1                      -0.006750    -0.001764        0.002791  ...
# diag_2                       0.005323     0.001167        0.005309  ...
# diag_3                       0.006463     0.001247       -0.004777  ...
# number_emergency             0.010179     0.004917       -0.004927  ...
# num_procedures               0.001661    -0.005013        0.005859  ...
# discharge_disposition_id    -0.005418    -0.011237        0.016133  ...
# gender                      -0.005137    -0.005626        0.003748  ...
# number_diagnoses             0.034618     0.013992       -0.011892  ...
# number_outpatient            0.002938     0.001317       -0.004891  ...
# number_inpatient             0.011592    -0.006916       -0.006572  ...
#
#                             diag_1    diag_2    diag_3  number_emergency  \
# readmitted               -0.022282 -0.007418  0.016961          0.060557
# race                     -0.000461 -0.025260 -0.000781          0.020388
# age                       0.019843  0.110208  0.046703         -0.091750
# time_in_hospital         -0.126978 -0.000740  0.086322         -0.010508
# num_lab_procedures       -0.066956  0.018852  0.041618         -0.002142
# num_medications          -0.005420  0.067330  0.068086          0.012127
# metformin                 0.031626 -0.024821 -0.020398         -0.008534
# repaglinide              -0.006750  0.005323  0.006463          0.010179
# nateglinide              -0.001764  0.001167  0.001247          0.004917
# chlorpropamide            0.002791  0.005309 -0.004777         -0.004927
# glimepiride               0.000784  0.014951 -0.003249          0.001440
# glipizide                 0.004696  0.011071 -0.001316         -0.003910
# glyburide                 0.010017  0.014761 -0.005318         -0.026041
# pioglitazone              0.023439 -0.009782 -0.004608          0.000029
# rosiglitazone             0.014311 -0.006292 -0.004539         -0.008049
# acarbose                  0.003093 -0.000731 -0.000018         -0.000439
# miglitol                  0.001657  0.003778 -0.001972          0.000374
# insulin                  -0.023767 -0.008518  0.010082          0.018930
# glyburide-metformin       0.015309 -0.001445  0.001118          0.002535
# glipizide-metformin       0.005107  0.001693 -0.003467         -0.002473
# glimepiride-pioglitazone  0.005107  0.001693 -0.003467         -0.002473
# diabetesMed              -0.022705 -0.020075 -0.004520          0.026318
# diag_1                    1.000000 -0.021044 -0.028096         -0.008390
# diag_2                   -0.021044  1.000000 -0.034641         -0.010988
# diag_3                   -0.028096 -0.034641  1.000000          0.002167
# number_emergency         -0.008390 -0.010988  0.002167          1.000000
# num_procedures           -0.014863  0.070645  0.042160         -0.038723
# discharge_disposition_id  0.017758 -0.003392  0.025873         -0.025990
# gender                   -0.035061  0.031512  0.005074         -0.020466
# number_diagnoses         -0.009697  0.041063  0.162407          0.054616
# number_outpatient        -0.010411 -0.015861  0.022858          0.091033
# number_inpatient         -0.048679  0.001689  0.011477          0.267174
#
#                           num_procedures  discharge_disposition_id    gender  \
# readmitted                     -0.012470                  0.050422 -0.002544
# race                           -0.013973                 -0.012343 -0.031277
# age                            -0.042699                  0.114274 -0.052631
# time_in_hospital                0.191164                  0.162903 -0.028961
# num_lab_procedures              0.058710                  0.022601 -0.002358
# num_medications                 0.382952                  0.106696 -0.022085
# metformin                      -0.037598                 -0.009119  0.000654
# repaglinide                     0.001661                 -0.005418 -0.005137
# nateglinide                    -0.005013                 -0.011237 -0.005626
# chlorpropamide                  0.005859                  0.016133  0.003748
# glimepiride                     0.008519                 -0.017283  0.000643
# glipizide                       0.002728                 -0.012513  0.027255
# glyburide                       0.002849                  0.038877  0.029201
# pioglitazone                    0.012107                 -0.012657  0.005895
# rosiglitazone                   0.011008                 -0.005661  0.010141
# acarbose                       -0.001782                  0.005835  0.011412
# miglitol                       -0.001104                  0.004646  0.002642
# insulin                         0.011880                 -0.021452  0.002786
# glyburide-metformin            -0.001476                 -0.004582  0.003795
# glipizide-metformin            -0.005475                  0.000368  0.007116
# glimepiride-pioglitazone       -0.005475                  0.000368  0.007116
# diabetesMed                    -0.004686                 -0.028127  0.015742
# diag_1                         -0.014863                  0.017758 -0.035061
# diag_2                          0.070645                 -0.003392  0.031512
# diag_3                          0.042160                  0.025873  0.005074
# number_emergency               -0.038723                 -0.025990 -0.020466
# num_procedures                  1.000000                  0.013879  0.061339
# discharge_disposition_id        0.013879                  1.000000 -0.020865
# gender                          0.061339                 -0.020865  1.000000
# number_diagnoses                0.058973                  0.038418 -0.001914
# number_outpatient              -0.026453                 -0.010278 -0.011791
# number_inpatient               -0.067535                  0.019037 -0.013857
#
#                           number_diagnoses  number_outpatient  \
# readmitted                        0.046491           0.018408
# race                             -0.080525          -0.043665
# age                               0.202696           0.020007
# time_in_hospital                  0.211225          -0.010913
# num_lab_procedures                0.150257          -0.008625
# num_medications                   0.241501           0.042652
# metformin                        -0.070561          -0.011537
# repaglinide                       0.034618           0.002938
# nateglinide                       0.013992           0.001317
# chlorpropamide                   -0.011892          -0.004891
# glimepiride                       0.008722          -0.011885
# glipizide                        -0.013014           0.004441
# glyburide                        -0.029824          -0.005166
# pioglitazone                     -0.000855           0.010772
# rosiglitazone                    -0.012091          -0.004045
# acarbose                          0.005950           0.012221
# miglitol                         -0.003422          -0.004049
# insulin                           0.034629           0.014249
# glyburide-metformin              -0.006911          -0.006554
# glipizide-metformin              -0.004185           0.001454
# glimepiride-pioglitazone         -0.004185           0.001454
# diabetesMed                       0.026647           0.017213
# diag_1                           -0.009697          -0.010411
# diag_2                            0.041063          -0.015861
# diag_3                            0.162407           0.022858
# number_emergency                  0.054616           0.091033
# num_procedures                    0.058973          -0.026453
# discharge_disposition_id          0.038418          -0.010278
# gender                           -0.001914          -0.011791
# number_diagnoses                  1.000000           0.091414
# number_outpatient                 0.091414           1.000000
# number_inpatient                  0.101244           0.105979
#
#                           number_inpatient
# readmitted                        0.163811
# race                             -0.004324
# age                              -0.049168
# time_in_hospital                  0.072282
# num_lab_procedures                0.039198
# num_medications                   0.062905
# metformin                        -0.065709
# repaglinide                       0.011592
# nateglinide                      -0.006916
# chlorpropamide                   -0.006572
# glimepiride                      -0.013086
# glipizide                        -0.024912
# glyburide                        -0.035085
# pioglitazone                     -0.026587
# rosiglitazone                    -0.019864
# acarbose                         -0.001110
# miglitol                         -0.006152
# insulin                           0.013542
# glyburide-metformin              -0.011518
# glipizide-metformin              -0.000982
# glimepiride-pioglitazone         -0.000982
# diabetesMed                       0.026846
# diag_1                           -0.048679
# diag_2                            0.001689
# diag_3                            0.011477
# number_emergency                  0.267174
# num_procedures                   -0.067535
# discharge_disposition_id          0.019037
# gender                           -0.013857
# number_diagnoses                  0.101244
# number_outpatient                 0.105979
# number_inpatient                  1.000000
#
# [32 rows x 32 columns]

# %%
#df3=df3[["diabetesMed","insulin","glipizide","age","time_in_hospital",	"num_lab_procedures",	"num_medications","repaglinide","nateglinide","readmitted"]]

# %%
df3
# Out:
#         readmitted  race  age  time_in_hospital  num_lab_procedures  \
# 1                0     1    2                 3                  59
# 2                0     2    3                 2                  11
# 3                0     1    4                 2                  44
# 4                0     1    5                 1                  51
# 5                0     1    6                 3                  31
# ...            ...   ...  ...               ...                 ...
# 101761           0     2    8                 3                  51
# 101762           0     2    9                 5                  33
# 101763           0     1    8                 1                  53
# 101764           0     1    9                10                  45
# 101765           0     1    8                 6                  13
#
#         num_medications  metformin  repaglinide  nateglinide  chlorpropamide  \
# 1                    18          1            1            1               1
# 2                    13          1            1            1               1
# 3                    16          1            1            1               1
# 4                     8          1            1            1               1
# 5                    16          1            1            1               1
# ...                 ...        ...          ...          ...             ...
# 101761               16          2            1            1               1
# 101762               18          1            1            1               1
# 101763                9          2            1            1               1
# 101764               21          1            1            1               1
# 101765                3          1            1            1               1
#
#         ...  diag_1  diag_2  diag_3  number_emergency  num_procedures  \
# 1       ...     2.0     2.0     2.0                 0               0
# 2       ...    10.0     2.0     0.0                 0               5
# 3       ...     0.0     2.0     6.0                 0               1
# 4       ...     1.0     1.0     2.0                 0               0
# 5       ...     6.0     6.0     2.0                 0               6
# ...     ...     ...     ...     ...               ...             ...
# 101761  ...     2.0     4.0     6.0                 0               0
# 101762  ...     8.0     2.0    15.0                 0               3
# 101763  ...     0.0     0.0     4.0                 0               0
# 101764  ...    16.0     3.0    16.0                 0               2
# 101765  ...     8.0     8.0    15.0                 0               3
#
#         discharge_disposition_id  gender  number_diagnoses  number_outpatient  \
# 1                              1     0.0                 9                  0
# 2                              1     0.0                 6                  2
# 3                              1     1.0                 7                  0
# 4                              1     1.0                 5                  0
# 5                              1     1.0                 9                  0
# ...                          ...     ...               ...                ...
# 101761                         3     1.0                 9                  0
# 101762                         4     0.0                 9                  0
# 101763                         1     1.0                13                  1
# 101764                         3     0.0                 9                  0
# 101765                         1     1.0                 9                  0
#
#         number_inpatient
# 1                      0
# 2                      1
# 3                      0
# 4                      0
# 5                      0
# ...                  ...
# 101761                 0
# 101762                 1
# 101763                 0
# 101764                 1
# 101765                 0
#
# [98052 rows x 32 columns]

# %%
x = df3.drop('readmitted', axis = 1)

# %%
y = df3['readmitted']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y, test_size = 0.1, random_state=0)

# %%
x_train
# Out:
#        race  age  time_in_hospital  num_lab_procedures  num_medications  \
# 30218     1    4                 3                  42                7
# 13309     1    7                10                  77               21
# 11329     1    9                 1                  30               11
# 8108      1    7                 4                  58               18
# 20538     2    7                 3                  23               18
# ...     ...  ...               ...                 ...              ...
# 22202     2    9                 6                  64               56
# 48199     2    8                 2                  52                8
# 44872     1    8                14                   1               11
# 45839     1    8                 8                  31               17
# 70890     1    8                 3                  56               19
#
#        metformin  repaglinide  nateglinide  chlorpropamide  glimepiride  ...  \
# 30218          1            1            1               1            1  ...
# 13309          2            1            1               1            1  ...
# 11329          1            1            1               1            1  ...
# 8108           2            1            1               1            1  ...
# 20538          1            1            1               1            1  ...
# ...          ...          ...          ...             ...          ...  ...
# 22202          1            1            1               1            1  ...
# 48199          1            1            1               1            1  ...
# 44872          1            1            1               1            1  ...
# 45839          2            1            1               1            1  ...
# 70890          1            1            1               1            1  ...
#
#        diag_1  diag_2  diag_3  number_emergency  num_procedures  \
# 30218     2.0     8.0     8.0                 0               3
# 13309     8.0     8.0     6.0                 0               5
# 11329    15.0     0.0     6.0                 0               0
# 8108      6.0     7.0     2.0                 0               0
# 20538    12.0     3.0     2.0                 0               1
# ...       ...     ...     ...               ...             ...
# 22202     6.0     0.0    16.0                 0               6
# 48199     6.0     7.0     2.0                 0               0
# 44872     7.0     6.0     6.0                 0               0
# 45839     7.0     0.0     7.0                 0               0
# 70890    15.0     2.0     5.0                 0               0
#
#        discharge_disposition_id  gender  number_diagnoses  number_outpatient  \
# 30218                         1     1.0                 6                  0
# 13309                         6     0.0                 9                  0
# 11329                        18     0.0                 8                  0
# 8108                          2     1.0                 5                  0
# 20538                         3     1.0                 7                  0
# ...                         ...     ...               ...                ...
# 22202                        11     0.0                 9                  0
# 48199                         1     1.0                 7                  0
# 44872                         3     0.0                 7                  0
# 45839                         6     0.0                 9                  0
# 70890                         3     1.0                 9                  1
#
#        number_inpatient
# 30218                 0
# 13309                 0
# 11329                 0
# 8108                  0
# 20538                 2
# ...                 ...
# 22202                 0
# 48199                 0
# 44872                 0
# 45839                 0
# 70890                 0
#
# [88246 rows x 31 columns]

# %%
from imblearn.over_sampling import SMOTE

# %%
x_train, y_train = SMOTE(sampling_strategy='minority').fit_resample(x_train, y_train)

# %%
# from imblearn.over_sampling import RandomOverSampler
# oversample = RandomOverSampler(sampling_strategy='minority')
# x_train, y_train = oversample.fit_resample(x_train, y_train)

# %%
# from imblearn.under_sampling import RandomUnderSampler
# undersample = RandomUnderSampler(sampling_strategy='majority')
# x_train, y_train = undersample.fit_resample(x_train, y_train)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)
print(X_train)
print(X_test)
# Out:
# [[-0.3811243  -2.04975076 -0.4736841  ... -0.87688073 -0.2711538
#   -0.5148903 ]
#  [-0.3811243  -0.01667837  1.94224682 ...  0.84422922 -0.2711538
#   -0.5148903 ]
#  [-0.3811243   1.33870322 -1.16395008 ...  0.2705259  -0.2711538
#   -0.5148903 ]
#  ...
#  [-0.3811243   0.66101243 -0.12855111 ... -0.87688073 -0.2711538
#   -0.5148903 ]
#  [-0.3811243  -1.37205996 -0.4736841  ... -1.45058405 -0.2711538
#   -0.5148903 ]
#  [-0.3811243   0.66101243 -1.16395008 ...  0.2705259  -0.2711538
#   -0.5148903 ]]
# [[-0.3811243   0.66101243 -0.4736841  ...  0.84422922 -0.2711538
#    0.20045704]
#  [ 1.32139333 -0.69436916 -0.81881709 ... -0.30317741  0.61418426
#    0.20045704]
#  [-0.3811243   0.66101243 -0.81881709 ...  0.84422922  0.61418426
#    1.63115172]
#  ...
#  [-0.3811243   0.66101243 -0.12855111 ...  0.84422922 -0.2711538
#    0.91580438]
#  [-0.3811243  -0.01667837 -1.16395008 ... -0.30317741 -0.2711538
#   -0.5148903 ]
#  [-0.3811243  -2.04975076 -0.4736841  ... -0.87688073 -0.2711538
#   -0.5148903 ]]

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier()
k.fit(X_train,y_train)
result=k.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, result)
print(cm)
# Out:
# [[6308 2419]
#  [ 704  375]]

# %%
print(accuracy_score(y_test,result))
# Out:
# 0.681521517438303

# %%
print(classification_report(y_test, result))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80      8727
#            1       0.13      0.35      0.19      1079
#
#     accuracy                           0.68      9806
#    macro avg       0.52      0.54      0.50      9806
# weighted avg       0.82      0.68      0.73      9806

# %%
x = df3.drop('readmitted', axis = 1)

# %%
y = df3['readmitted']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y,test_size=0.2,random_state=0,stratify=df.readmitted)
print(X_train)
print(Y_train)
print(Y_test)
print(Y_test)
# Out:
#        race  age  time_in_hospital  num_lab_procedures  num_medications  \
# 94989     1    5                 2                  50               16
# 28316     1    7                 4                  54               14
# 10107     1    6                 9                  55               41
# 64921     1    8                 4                  32               19
# 96459     1    9                 3                  43               15
# ...     ...  ...               ...                 ...              ...
# 2883      1    6                12                  83               43
# 41268     1    6                 1                  54                8
# 25200     1    6                10                  58               19
# 20737     1    7                 3                  59               11
# 10749     1    7                 3                  22                6
#
#        metformin  repaglinide  nateglinide  chlorpropamide  glimepiride  ...  \
# 94989          2            1            1               1            1  ...
# 28316          2            1            1               1            1  ...
# 10107          1            1            1               1            1  ...
# 64921          1            1            1               1            1  ...
# 96459          1            1            1               1            1  ...
# ...          ...          ...          ...             ...          ...  ...
# 2883           1            1            1               1            1  ...
# 41268          1            1            1               1            1  ...
# 25200          1            1            1               1            1  ...
# 20737          1            1            1               1            1  ...
# 10749          1            1            1               1            1  ...
#
#        diag_1  diag_2  diag_3  number_emergency  num_procedures  \
# 94989     4.0     4.0     0.0                 0               1
# 28316     2.0     7.0     0.0                 0               1
# 10107     6.0     5.0     6.0                 0               6
# 64921     6.0     6.0     9.0                 0               2
# 96459     7.0     2.0     3.0                 0               0
# ...       ...     ...     ...               ...             ...
# 2883      6.0     4.0     7.0                 1               6
# 41268     6.0     2.0     2.0                 0               6
# 25200     0.0     0.0    11.0                 0               5
# 20737     0.0     6.0     9.0                 0               3
# 10749     2.0     1.0     8.0                 0               0
#
#        discharge_disposition_id  gender  number_diagnoses  number_outpatient  \
# 94989                         5     1.0                 9                  0
# 28316                         1     1.0                 5                  0
# 10107                        18     1.0                 7                  0
# 64921                         1     1.0                 6                  0
# 96459                         1     0.0                 9                  1
# ...                         ...     ...               ...                ...
# 2883                          1     1.0                 9                  0
# 41268                         1     0.0                 4                  0
# 25200                         1     1.0                 9                  0
# 20737                         1     0.0                 6                  0
# 10749                         5     1.0                 8                  1
#
#        number_inpatient
# 94989                 1
# 28316                 0
# 10107                 0
# 64921                 3
# 96459                 0
# ...                 ...
# 2883                  1
# 41268                 0
# 25200                 1
# 20737                 0
# 10749                 2
#
# [78441 rows x 31 columns]
# 94989    0
# 28316    0
# 10107    0
# 64921    0
# 96459    0
#         ..
# 2883     0
# 41268    0
# 25200    0
# 20737    0
# 10749    0
# Name: readmitted, Length: 78441, dtype: int64
# 70120    0
# 76615    0
# 2276     0
# 49346    0
# 83425    0
#         ..
# 92199    0
# 76540    0
# 60688    0
# 24529    1
# 45640    0
# Name: readmitted, Length: 19611, dtype: int64
# 70120    0
# 76615    0
# 2276     0
# 49346    0
# 83425    0
#         ..
# 92199    0
# 76540    0
# 60688    0
# 24529    1
# 45640    0
# Name: readmitted, Length: 19611, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler
undersample = RandomUnderSampler(sampling_strategy='majority')
X_train, Y_train = undersample.fit_resample(X_train,Y_train)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
print(X_train)
print(X_test)
# Out:
# [[ 1.01630228  0.54166087  2.13217559 ...  0.77695271 -0.31941423
#   -0.5528125 ]
#  [ 1.01630228  0.54166087  3.12936605 ...  0.77695271 -0.31941423
#   -0.5528125 ]
#  [-0.45661645  0.54166087 -1.19179259 ...  0.77695271 -0.31941423
#   -0.5528125 ]
#  ...
#  [-0.45661645 -0.73208205 -1.19179259 ...  0.21682548  0.4622787
#    3.13732814]
#  [-0.45661645  0.54166087 -0.52699895 ...  0.77695271 -0.31941423
#    0.06221094]
#  [-0.45661645  1.17853233 -0.52699895 ... -0.34330174 -0.31941423
#   -0.5528125 ]]
# [[ 1.01630228 -0.73208205  0.13779468 ...  0.77695271 -0.31941423
#   -0.5528125 ]
#  [-0.45661645 -0.09521059  1.13498514 ...  0.77695271 -0.31941423
#   -0.5528125 ]
#  [ 1.01630228 -0.09521059 -1.19179259 ... -1.46355619 -0.31941423
#   -0.5528125 ]
#  ...
#  [-0.45661645  0.54166087 -0.19460214 ...  0.77695271  1.24397162
#   -0.5528125 ]
#  [-0.45661645 -0.09521059 -0.85939577 ...  0.77695271 -0.31941423
#   -0.5528125 ]
#  [-0.45661645 -2.00582497  0.4701915  ...  0.77695271 -0.31941423
#   -0.5528125 ]]

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
Y_predic=rf.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(Y_test,Y_predic)
print(cm)
# Out:
# [[10884  6514]
#  [  898  1315]]

# %%
accuracy_score(Y_test,Y_predic)
# Out:
# 0.6220488501351282
